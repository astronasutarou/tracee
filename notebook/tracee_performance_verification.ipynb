# %%
import numpy as np
import tracee
param = tracee.default_parameters()
param.limit = 10

# %%
basename = 'sample/mockdata_N005F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N005F030D200d00_1401.txt
# ## 590 edges found
# ## 5 tracklets found.
# ## timeit for generate_edge:
# 15.7 ms ± 366 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ## timeit for extract:
# 32.5 ms ± 529 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N005F030D200d00_1402.txt
# ## 617 edges found
# ## 5 tracklets found.
# ## timeit for generate_edge:
# 17 ms ± 380 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ## timeit for extract:
# 29.5 ms ± 449 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N005F030D200d00_1403.txt
# ## 633 edges found
# ## 5 tracklets found.
# ## timeit for generate_edge:
# 17 ms ± 525 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ## timeit for extract:
# 31.9 ms ± 402 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N005F030D200d00_1404.txt
# ## 615 edges found
# ## 5 tracklets found.
# ## timeit for generate_edge:
# 16.4 ms ± 333 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ## timeit for extract:
# 31.5 ms ± 638 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N005F030D200d00_1405.txt
# ## 632 edges found
# ## 5 tracklets found.
# ## timeit for generate_edge:
# 17.1 ms ± 572 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ## timeit for extract:
# 35.5 ms ± 332 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
basename = 'sample/mockdata_N010F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N010F030D200d00_1401.txt
# ## 838 edges found
# ## 10 tracklets found.
# ## timeit for generate_edge:
# 24.5 ms ± 350 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 55.9 ms ± 3.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N010F030D200d00_1402.txt
# ## 882 edges found
# ## 10 tracklets found.
# ## timeit for generate_edge:
# 28.7 ms ± 2.85 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 56.7 ms ± 890 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N010F030D200d00_1403.txt
# ## 837 edges found
# ## 10 tracklets found.
# ## timeit for generate_edge:
# 24.2 ms ± 312 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 55 ms ± 2.55 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N010F030D200d00_1404.txt
# ## 921 edges found
# ## 10 tracklets found.
# ## timeit for generate_edge:
# 27.1 ms ± 571 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 68.9 ms ± 2.82 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N010F030D200d00_1405.txt
# ## 914 edges found
# ## 10 tracklets found.
# ## timeit for generate_edge:
# 28.9 ms ± 848 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 64.9 ms ± 1.86 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
basename = 'sample/mockdata_N025F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N025F030D200d00_1401.txt
# ## 1584 edges found
# ## 25 tracklets found.
# ## timeit for generate_edge:
# 59.2 ms ± 1.59 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 130 ms ± 1.42 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N025F030D200d00_1402.txt
# ## 1622 edges found
# ## 24 tracklets found.
# ## timeit for generate_edge:
# 62.9 ms ± 2.78 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 131 ms ± 5.76 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N025F030D200d00_1403.txt
# ## 1527 edges found
# ## 24 tracklets found.
# ## timeit for generate_edge:
# 57.1 ms ± 1.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 133 ms ± 6.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N025F030D200d00_1404.txt
# ## 1598 edges found
# ## 25 tracklets found.
# ## timeit for generate_edge:
# 61 ms ± 1.42 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 137 ms ± 1.17 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# # filename: sample/mockdata_N025F030D200d00_1405.txt
# ## 1555 edges found
# ## 25 tracklets found.
# ## timeit for generate_edge:
# 58.2 ms ± 1.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 137 ms ± 5.48 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
basename = 'sample/mockdata_N050F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N050F030D200d00_1401.txt
# ## 2825 edges found
# ## 50 tracklets found.
# ## timeit for generate_edge:
# 144 ms ± 6.69 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 344 ms ± 10.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N050F030D200d00_1402.txt
# ## 2938 edges found
# ## 49 tracklets found.
# ## timeit for generate_edge:
# 151 ms ± 2.89 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 395 ms ± 32.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N050F030D200d00_1403.txt
# ## 2628 edges found
# ## 47 tracklets found.
# ## timeit for generate_edge:
# 134 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 322 ms ± 7.46 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N050F030D200d00_1404.txt
# ## 2853 edges found
# ## 50 tracklets found.
# ## timeit for generate_edge:
# 149 ms ± 2.82 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 344 ms ± 3.41 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N050F030D200d00_1405.txt
# ## 2907 edges found
# ## 49 tracklets found.
# ## timeit for generate_edge:
# 149 ms ± 3.53 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# ## timeit for extract:
# 376 ms ± 7.01 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
basename = 'sample/mockdata_N100F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N100F030D200d00_1401.txt
# ## 5334 edges found
# ## 98 tracklets found.
# ## timeit for generate_edge:
# 409 ms ± 15 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.09 s ± 63.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N100F030D200d00_1402.txt
# ## 5302 edges found
# ## 98 tracklets found.
# ## timeit for generate_edge:
# 410 ms ± 30.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.05 s ± 31 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N100F030D200d00_1403.txt
# ## 5345 edges found
# ## 97 tracklets found.
# ## timeit for generate_edge:
# 383 ms ± 11.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.04 s ± 35 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N100F030D200d00_1404.txt
# ## 5200 edges found
# ## 100 tracklets found.
# ## timeit for generate_edge:
# 392 ms ± 32.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.02 s ± 23 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N100F030D200d00_1405.txt
# ## 5177 edges found
# ## 98 tracklets found.
# ## timeit for generate_edge:
# 361 ms ± 4.67 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.08 s ± 64.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
basename = 'sample/mockdata_N125F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N125F030D200d00_1401.txt
# ## 6332 edges found
# ## 117 tracklets found.
# ## timeit for generate_edge:
# 533 ms ± 38.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.6 s ± 42.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N125F030D200d00_1402.txt
# ## 6645 edges found
# ## 120 tracklets found.
# ## timeit for generate_edge:
# 546 ms ± 14 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.59 s ± 56.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N125F030D200d00_1403.txt
# ## 6541 edges found
# ## 114 tracklets found.
# ## timeit for generate_edge:
# 541 ms ± 35 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.55 s ± 55.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N125F030D200d00_1404.txt
# ## 6324 edges found
# ## 117 tracklets found.
# ## timeit for generate_edge:
# 520 ms ± 15.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.44 s ± 70.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N125F030D200d00_1405.txt
# ## 6683 edges found
# ## 120 tracklets found.
# ## timeit for generate_edge:
# 559 ms ± 17.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 1.62 s ± 49.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
basename = 'sample/mockdata_N150F030D200d00_{}.txt'
for n in range(1401,1406):
    filename = basename.format(n)
    data = np.loadtxt(filename)
    print(f'# filename: {filename}')
    edge = tracee.generate_edge(data, 3, 200)
    tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('## {} edges found'.format(len(edge)))
    print('## {} tracklets found.'.format(len(tracklet)))
    print('## timeit for generate_edge:')
    # %timeit edge = tracee.generate_edge(data, 3, 200)
    print('## timeit for extract:')
    # %timeit tracklet = tracee.extract(data, n_neighbor=3, param=param)
    print('')
# Out:
# # filename: sample/mockdata_N150F030D200d00_1401.txt
# ## 7562 edges found
# ## 137 tracklets found.
# ## timeit for generate_edge:
# 747 ms ± 28.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 2.13 s ± 159 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N150F030D200d00_1402.txt
# ## 7625 edges found
# ## 133 tracklets found.
# ## timeit for generate_edge:
# 764 ms ± 19.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 2.14 s ± 74.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N150F030D200d00_1403.txt
# ## 7550 edges found
# ## 140 tracklets found.
# ## timeit for generate_edge:
# 768 ms ± 20.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 2.07 s ± 41.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N150F030D200d00_1404.txt
# ## 7663 edges found
# ## 139 tracklets found.
# ## timeit for generate_edge:
# 741 ms ± 15.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 2.19 s ± 116 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
#
# # filename: sample/mockdata_N150F030D200d00_1405.txt
# ## 7657 edges found
# ## 134 tracklets found.
# ## timeit for generate_edge:
# 759 ms ± 28.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# ## timeit for extract:
# 2.15 s ± 85 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
